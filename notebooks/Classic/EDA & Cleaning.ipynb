# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('owid-energy-data.csv')

# %%
df.shape
# Out:
# (21813, 130)

# %%
df.head()
# Out:
#          country  year iso_code  population  gdp  biofuel_cons_change_pct  \
# 0  ASEAN (Ember)  2000      NaN         NaN  NaN                      NaN
# 1  ASEAN (Ember)  2001      NaN         NaN  NaN                      NaN
# 2  ASEAN (Ember)  2002      NaN         NaN  NaN                      NaN
# 3  ASEAN (Ember)  2003      NaN         NaN  NaN                      NaN
# 4  ASEAN (Ember)  2004      NaN         NaN  NaN                      NaN
#
#    biofuel_cons_change_twh  biofuel_cons_per_capita  biofuel_consumption  \
# 0                      NaN                      NaN                  NaN
# 1                      NaN                      NaN                  NaN
# 2                      NaN                      NaN                  NaN
# 3                      NaN                      NaN                  NaN
# 4                      NaN                      NaN                  NaN
#
#    biofuel_elec_per_capita  ...  solar_share_elec  solar_share_energy  \
# 0                      NaN  ...               0.0                 NaN
# 1                      NaN  ...               0.0                 NaN
# 2                      NaN  ...               0.0                 NaN
# 3                      NaN  ...               0.0                 NaN
# 4                      NaN  ...               0.0                 NaN
#
#    wind_cons_change_pct  wind_cons_change_twh  wind_consumption  \
# 0                   NaN                   NaN               NaN
# 1                   NaN                   NaN               NaN
# 2                   NaN                   NaN               NaN
# 3                   NaN                   NaN               NaN
# 4                   NaN                   NaN               NaN
#
#    wind_elec_per_capita  wind_electricity  wind_energy_per_capita  \
# 0                   NaN               0.0                     NaN
# 1                   NaN               0.0                     NaN
# 2                   NaN               0.0                     NaN
# 3                   NaN               0.0                     NaN
# 4                   NaN               0.0                     NaN
#
#    wind_share_elec  wind_share_energy
# 0              0.0                NaN
# 1              0.0                NaN
# 2              0.0                NaN
# 3              0.0                NaN
# 4              0.0                NaN
#
# [5 rows x 130 columns]

# %%
pd.options.display.max_columns = 140

# %%
df.iloc[:,:70].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21813 entries, 0 to 21812
# Data columns (total 70 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   country                        21813 non-null  object
#  1   year                           21813 non-null  int64
#  2   iso_code                       16813 non-null  object
#  3   population                     18448 non-null  float64
#  4   gdp                            11775 non-null  float64
#  5   biofuel_cons_change_pct        1806 non-null   float64
#  6   biofuel_cons_change_twh        2796 non-null   float64
#  7   biofuel_cons_per_capita        2400 non-null   float64
#  8   biofuel_consumption            2876 non-null   float64
#  9   biofuel_elec_per_capita        5570 non-null   float64
#  10  biofuel_electricity            5834 non-null   float64
#  11  biofuel_share_elec             5811 non-null   float64
#  12  biofuel_share_energy           2778 non-null   float64
#  13  carbon_intensity_elec          5835 non-null   float64
#  14  coal_cons_change_pct           5298 non-null   float64
#  15  coal_cons_change_twh           5416 non-null   float64
#  16  coal_cons_per_capita           4754 non-null   float64
#  17  coal_consumption               5521 non-null   float64
#  18  coal_elec_per_capita           6095 non-null   float64
#  19  coal_electricity               6710 non-null   float64
#  20  coal_prod_change_pct           9657 non-null   float64
#  21  coal_prod_change_twh           16293 non-null  float64
#  22  coal_prod_per_capita           14763 non-null  float64
#  23  coal_production                16548 non-null  float64
#  24  coal_share_elec                6687 non-null   float64
#  25  coal_share_energy              4903 non-null   float64
#  26  electricity_demand             5863 non-null   float64
#  27  electricity_demand_per_capita  5599 non-null   float64
#  28  electricity_generation         7412 non-null   float64
#  29  electricity_share_energy       3962 non-null   float64
#  30  energy_cons_change_pct         11722 non-null  float64
#  31  energy_cons_change_twh         11915 non-null  float64
#  32  energy_per_capita              10694 non-null  float64
#  33  energy_per_gdp                 7790 non-null   float64
#  34  fossil_cons_change_pct         4955 non-null   float64
#  35  fossil_cons_change_twh         4955 non-null   float64
#  36  fossil_elec_per_capita         6114 non-null   float64
#  37  fossil_electricity             6729 non-null   float64
#  38  fossil_energy_per_capita       4300 non-null   float64
#  39  fossil_fuel_consumption        5060 non-null   float64
#  40  fossil_share_elec              6701 non-null   float64
#  41  fossil_share_energy            4903 non-null   float64
#  42  gas_cons_change_pct            5150 non-null   float64
#  43  gas_cons_change_twh            5211 non-null   float64
#  44  gas_consumption                5315 non-null   float64
#  45  gas_elec_per_capita            5999 non-null   float64
#  46  gas_electricity                6614 non-null   float64
#  47  gas_energy_per_capita          4555 non-null   float64
#  48  gas_prod_change_pct            7775 non-null   float64
#  49  gas_prod_change_twh            16586 non-null  float64
#  50  gas_prod_per_capita            14957 non-null  float64
#  51  gas_production                 16841 non-null  float64
#  52  gas_share_elec                 6591 non-null   float64
#  53  gas_share_energy               4903 non-null   float64
#  54  greenhouse_gas_emissions       5863 non-null   float64
#  55  hydro_cons_change_pct          5140 non-null   float64
#  56  hydro_cons_change_twh          5494 non-null   float64
#  57  hydro_consumption              5599 non-null   float64
#  58  hydro_elec_per_capita          8030 non-null   float64
#  59  hydro_electricity              9061 non-null   float64
#  60  hydro_energy_per_capita        4832 non-null   float64
#  61  hydro_share_elec               7285 non-null   float64
#  62  hydro_share_energy             4903 non-null   float64
#  63  low_carbon_cons_change_pct     5217 non-null   float64
#  64  low_carbon_cons_change_twh     5494 non-null   float64
#  65  low_carbon_consumption         5599 non-null   float64
#  66  low_carbon_elec_per_capita     7160 non-null   float64
#  67  low_carbon_electricity         7998 non-null   float64
#  68  low_carbon_energy_per_capita   4832 non-null   float64
#  69  low_carbon_share_elec          7075 non-null   float64
# dtypes: float64(67), int64(1), object(2)
# memory usage: 11.6+ MB

# %%
df.iloc[:,-60:].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21813 entries, 0 to 21812
# Data columns (total 60 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   low_carbon_share_energy                       4903 non-null   float64
#  1   net_elec_imports                              5575 non-null   float64
#  2   net_elec_imports_share_demand                 5547 non-null   float64
#  3   nuclear_cons_change_pct                       2482 non-null   float64
#  4   nuclear_cons_change_twh                       6837 non-null   float64
#  5   nuclear_consumption                           6976 non-null   float64
#  6   nuclear_elec_per_capita                       8758 non-null   float64
#  7   nuclear_electricity                           9683 non-null   float64
#  8   nuclear_energy_per_capita                     6315 non-null   float64
#  9   nuclear_share_elec                            7204 non-null   float64
#  10  nuclear_share_energy                          4765 non-null   float64
#  11  oil_cons_change_pct                           5712 non-null   float64
#  12  oil_cons_change_twh                           5712 non-null   float64
#  13  oil_consumption                               5816 non-null   float64
#  14  oil_elec_per_capita                           6034 non-null   float64
#  15  oil_electricity                               6649 non-null   float64
#  16  oil_energy_per_capita                         5049 non-null   float64
#  17  oil_prod_change_pct                           9794 non-null   float64
#  18  oil_prod_change_twh                           17225 non-null  float64
#  19  oil_prod_per_capita                           15435 non-null  float64
#  20  oil_production                                17482 non-null  float64
#  21  oil_share_elec                                6626 non-null   float64
#  22  oil_share_energy                              4903 non-null   float64
#  23  other_renewable_consumption                   5081 non-null   float64
#  24  other_renewable_electricity                   8427 non-null   float64
#  25  other_renewable_exc_biofuel_electricity       5270 non-null   float64
#  26  other_renewables_cons_change_pct              3641 non-null   float64
#  27  other_renewables_cons_change_twh              4976 non-null   float64
#  28  other_renewables_elec_per_capita              7465 non-null   float64
#  29  other_renewables_elec_per_capita_exc_biofuel  5006 non-null   float64
#  30  other_renewables_energy_per_capita            4383 non-null   float64
#  31  other_renewables_share_elec                   7195 non-null   float64
#  32  other_renewables_share_elec_exc_biofuel       5247 non-null   float64
#  33  other_renewables_share_energy                 4424 non-null   float64
#  34  per_capita_electricity                        6641 non-null   float64
#  35  primary_energy_consumption                    12180 non-null  float64
#  36  renewables_cons_change_pct                    5210 non-null   float64
#  37  renewables_cons_change_twh                    5494 non-null   float64
#  38  renewables_consumption                        5599 non-null   float64
#  39  renewables_elec_per_capita                    7160 non-null   float64
#  40  renewables_electricity                        8110 non-null   float64
#  41  renewables_energy_per_capita                  4832 non-null   float64
#  42  renewables_share_elec                         7153 non-null   float64
#  43  renewables_share_energy                       4903 non-null   float64
#  44  solar_cons_change_pct                         2233 non-null   float64
#  45  solar_cons_change_twh                         4680 non-null   float64
#  46  solar_consumption                             4786 non-null   float64
#  47  solar_elec_per_capita                         7253 non-null   float64
#  48  solar_electricity                             8203 non-null   float64
#  49  solar_energy_per_capita                       4100 non-null   float64
#  50  solar_share_elec                              7184 non-null   float64
#  51  solar_share_energy                            4151 non-null   float64
#  52  wind_cons_change_pct                          2510 non-null   float64
#  53  wind_cons_change_twh                          4742 non-null   float64
#  54  wind_consumption                              4847 non-null   float64
#  55  wind_elec_per_capita                          7279 non-null   float64
#  56  wind_electricity                              8235 non-null   float64
#  57  wind_energy_per_capita                        4155 non-null   float64
#  58  wind_share_elec                               7198 non-null   float64
#  59  wind_share_energy                             4217 non-null   float64
# dtypes: float64(60)
# memory usage: 10.0 MB

# %%
df.iloc[:,:70].isnull().sum().sort_values(ascending=False).head(50)
# Out:
# biofuel_cons_change_pct          20007
# biofuel_cons_per_capita          19413
# biofuel_share_energy             19035
# biofuel_cons_change_twh          19017
# biofuel_consumption              18937
# electricity_share_energy         17851
# fossil_energy_per_capita         17513
# gas_energy_per_capita            17258
# coal_cons_per_capita             17059
# low_carbon_energy_per_capita     16981
# hydro_energy_per_capita          16981
# hydro_share_energy               16910
# gas_share_energy                 16910
# coal_share_energy                16910
# fossil_share_energy              16910
# fossil_cons_change_twh           16858
# fossil_cons_change_pct           16858
# fossil_fuel_consumption          16753
# hydro_cons_change_pct            16673
# gas_cons_change_pct              16663
# gas_cons_change_twh              16602
# low_carbon_cons_change_pct       16596
# coal_cons_change_pct             16515
# gas_consumption                  16498
# coal_cons_change_twh             16397
# low_carbon_cons_change_twh       16319
# hydro_cons_change_twh            16319
# coal_consumption                 16292
# biofuel_elec_per_capita          16243
# hydro_consumption                16214
# electricity_demand_per_capita    16214
# low_carbon_consumption           16214
# biofuel_share_elec               16002
# biofuel_electricity              15979
# carbon_intensity_elec            15978
# greenhouse_gas_emissions         15950
# electricity_demand               15950
# gas_elec_per_capita              15814
# coal_elec_per_capita             15718
# fossil_elec_per_capita           15699
# gas_share_elec                   15222
# gas_electricity                  15199
# coal_share_elec                  15126
# fossil_share_elec                15112
# coal_electricity                 15103
# fossil_electricity               15084
# low_carbon_share_elec            14738
# low_carbon_elec_per_capita       14653
# hydro_share_elec                 14528
# electricity_generation           14401
# dtype: int64

# %%
df['primary_energy_consumption']
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#           ...
# 21808    46.120
# 21809    41.997
# 21810    42.145
# 21811       NaN
# 21812       NaN
# Name: primary_energy_consumption, Length: 21813, dtype: float64

# %%
cols_to_drop = [
    # Identifiers & Metadata (Not useful for prediction)
    "country",
    "iso_code",
    "year",
    
    # Weakly Related or Indirect Features
    "biofuel_share_energy",
    "coal_share_energy",
    "electricity_share_energy",
    "fossil_share_energy",
    "gas_share_energy",
    "hydro_share_energy",
    "low_carbon_share_energy",
    "nuclear_share_energy",
    "oil_share_energy",
    "other_renewables_share_energy",
    "renewables_share_energy",
    "solar_share_energy",
    "wind_share_energy",
    
    # Change Percentage Columns (Derivable from absolute values)
    "biofuel_cons_change_pct",
    "coal_cons_change_pct",
    "energy_cons_change_pct",
    "fossil_cons_change_pct",
    "gas_cons_change_pct",
    "hydro_cons_change_pct",
    "low_carbon_cons_change_pct",
    "nuclear_cons_change_pct",
    "oil_cons_change_pct",
    "other_renewables_cons_change_pct",
    "renewables_cons_change_pct",
    "solar_cons_change_pct",
    "wind_cons_change_pct",
    
    # Per Capita & GDP-Based Columns (We focus on total energy)
    "biofuel_cons_per_capita",
    "coal_cons_per_capita",
    "electricity_demand_per_capita",
    "energy_per_capita",
    "energy_per_gdp",
    "fossil_elec_per_capita",
    "fossil_energy_per_capita",
    "gas_elec_per_capita",
    "gas_energy_per_capita",
    "hydro_elec_per_capita",
    "hydro_energy_per_capita",
    "low_carbon_elec_per_capita",
    "low_carbon_energy_per_capita",
    "nuclear_elec_per_capita",
    "nuclear_energy_per_capita",
    "oil_elec_per_capita",
    "oil_energy_per_capita",
    "other_renewables_elec_per_capita",
    "other_renewables_energy_per_capita",
    "per_capita_electricity",
    "renewables_elec_per_capita",
    "renewables_energy_per_capita",
    "solar_elec_per_capita",
    "solar_energy_per_capita",
    "wind_elec_per_capita",
    "wind_energy_per_capita",
    
    # Electricity Share-Based Columns (Use absolute values instead)
    "biofuel_share_elec",
    "coal_share_elec",
    "fossil_share_elec",
    "gas_share_elec",
    "hydro_share_elec",
    "low_carbon_share_elec",
    "nuclear_share_elec",
    "oil_share_elec",
    "other_renewables_share_elec",
    "renewables_share_elec",
    "solar_share_elec",
    "wind_share_elec",
    
    # Electricity Imports (Not directly related to consumption prediction)
    "net_elec_imports",
    "net_elec_imports_share_demand",
    
    # Greenhouse Gas Emissions (Useful for climate studies, but not directly for energy prediction)
    "greenhouse_gas_emissions"
]

# %%
df.drop(columns=cols_to_drop,inplace=True)

# %%
df.shape
# Out:
# (21813, 60)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21813 entries, 0 to 21812
# Data columns (total 60 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   population                                    18448 non-null  float64
#  1   gdp                                           11775 non-null  float64
#  2   biofuel_cons_change_twh                       2796 non-null   float64
#  3   biofuel_consumption                           2876 non-null   float64
#  4   biofuel_elec_per_capita                       5570 non-null   float64
#  5   biofuel_electricity                           5834 non-null   float64
#  6   carbon_intensity_elec                         5835 non-null   float64
#  7   coal_cons_change_twh                          5416 non-null   float64
#  8   coal_consumption                              5521 non-null   float64
#  9   coal_elec_per_capita                          6095 non-null   float64
#  10  coal_electricity                              6710 non-null   float64
#  11  coal_prod_change_pct                          9657 non-null   float64
#  12  coal_prod_change_twh                          16293 non-null  float64
#  13  coal_prod_per_capita                          14763 non-null  float64
#  14  coal_production                               16548 non-null  float64
#  15  electricity_demand                            5863 non-null   float64
#  16  electricity_generation                        7412 non-null   float64
#  17  energy_cons_change_twh                        11915 non-null  float64
#  18  fossil_cons_change_twh                        4955 non-null   float64
#  19  fossil_electricity                            6729 non-null   float64
#  20  fossil_fuel_consumption                       5060 non-null   float64
#  21  gas_cons_change_twh                           5211 non-null   float64
#  22  gas_consumption                               5315 non-null   float64
#  23  gas_electricity                               6614 non-null   float64
#  24  gas_prod_change_pct                           7775 non-null   float64
#  25  gas_prod_change_twh                           16586 non-null  float64
#  26  gas_prod_per_capita                           14957 non-null  float64
#  27  gas_production                                16841 non-null  float64
#  28  hydro_cons_change_twh                         5494 non-null   float64
#  29  hydro_consumption                             5599 non-null   float64
#  30  hydro_electricity                             9061 non-null   float64
#  31  low_carbon_cons_change_twh                    5494 non-null   float64
#  32  low_carbon_consumption                        5599 non-null   float64
#  33  low_carbon_electricity                        7998 non-null   float64
#  34  nuclear_cons_change_twh                       6837 non-null   float64
#  35  nuclear_consumption                           6976 non-null   float64
#  36  nuclear_electricity                           9683 non-null   float64
#  37  oil_cons_change_twh                           5712 non-null   float64
#  38  oil_consumption                               5816 non-null   float64
#  39  oil_electricity                               6649 non-null   float64
#  40  oil_prod_change_pct                           9794 non-null   float64
#  41  oil_prod_change_twh                           17225 non-null  float64
#  42  oil_prod_per_capita                           15435 non-null  float64
#  43  oil_production                                17482 non-null  float64
#  44  other_renewable_consumption                   5081 non-null   float64
#  45  other_renewable_electricity                   8427 non-null   float64
#  46  other_renewable_exc_biofuel_electricity       5270 non-null   float64
#  47  other_renewables_cons_change_twh              4976 non-null   float64
#  48  other_renewables_elec_per_capita_exc_biofuel  5006 non-null   float64
#  49  other_renewables_share_elec_exc_biofuel       5247 non-null   float64
#  50  primary_energy_consumption                    12180 non-null  float64
#  51  renewables_cons_change_twh                    5494 non-null   float64
#  52  renewables_consumption                        5599 non-null   float64
#  53  renewables_electricity                        8110 non-null   float64
#  54  solar_cons_change_twh                         4680 non-null   float64
#  55  solar_consumption                             4786 non-null   float64
#  56  solar_electricity                             8203 non-null   float64
#  57  wind_cons_change_twh                          4742 non-null   float64
#  58  wind_consumption                              4847 non-null   float64
#  59  wind_electricity                              8235 non-null   float64
# dtypes: float64(60)
# memory usage: 10.0 MB

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# biofuel_cons_change_twh                         19017
# biofuel_consumption                             18937
# solar_cons_change_twh                           17133
# wind_cons_change_twh                            17071
# solar_consumption                               17027
# wind_consumption                                16966
# fossil_cons_change_twh                          16858
# other_renewables_cons_change_twh                16837
# other_renewables_elec_per_capita_exc_biofuel    16807
# fossil_fuel_consumption                         16753
# other_renewable_consumption                     16732
# gas_cons_change_twh                             16602
# other_renewables_share_elec_exc_biofuel         16566
# other_renewable_exc_biofuel_electricity         16543
# gas_consumption                                 16498
# coal_cons_change_twh                            16397
# hydro_cons_change_twh                           16319
# renewables_cons_change_twh                      16319
# low_carbon_cons_change_twh                      16319
# coal_consumption                                16292
# biofuel_elec_per_capita                         16243
# low_carbon_consumption                          16214
# renewables_consumption                          16214
# hydro_consumption                               16214
# oil_cons_change_twh                             16101
# oil_consumption                                 15997
# biofuel_electricity                             15979
# carbon_intensity_elec                           15978
# electricity_demand                              15950
# coal_elec_per_capita                            15718
# gas_electricity                                 15199
# oil_electricity                                 15164
# coal_electricity                                15103
# fossil_electricity                              15084
# nuclear_cons_change_twh                         14976
# nuclear_consumption                             14837
# electricity_generation                          14401
# gas_prod_change_pct                             14038
# low_carbon_electricity                          13815
# renewables_electricity                          13703
# solar_electricity                               13610
# wind_electricity                                13578
# other_renewable_electricity                     13386
# hydro_electricity                               12752
# coal_prod_change_pct                            12156
# nuclear_electricity                             12130
# oil_prod_change_pct                             12019
# gdp                                             10038
# energy_cons_change_twh                           9898
# primary_energy_consumption                       9633
# coal_prod_per_capita                             7050
# gas_prod_per_capita                              6856
# oil_prod_per_capita                              6378
# coal_prod_change_twh                             5520
# coal_production                                  5265
# gas_prod_change_twh                              5227
# gas_production                                   4972
# oil_prod_change_twh                              4588
# oil_production                                   4331
# population                                       3365
# dtype: int64

# %%
cols_to_drop.clear()

# %%
cols_to_drop.extend([
    "biofuel_cons_change_twh",
    "biofuel_consumption",
    "solar_cons_change_twh",
    "wind_cons_change_twh",
    "solar_consumption",
    "wind_consumption",
    "fossil_cons_change_twh",
    "other_renewables_cons_change_twh",
    "other_renewables_elec_per_capita_exc_biofuel",
    "fossil_fuel_consumption",
    "other_renewable_consumption",
    "gas_cons_change_twh",
    "other_renewables_share_elec_exc_biofuel",
    "other_renewable_exc_biofuel_electricity",
    "gas_consumption",
    "coal_cons_change_twh",
    "hydro_cons_change_twh",
    "renewables_cons_change_twh",
    "low_carbon_cons_change_twh",
    "coal_consumption",
    "biofuel_elec_per_capita",
    "low_carbon_consumption",
    "renewables_consumption",
    "hydro_consumption",
    "oil_cons_change_twh",
    "oil_consumption",
    "biofuel_electricity",
    "carbon_intensity_elec",
    "electricity_demand"
])

# %%
df.drop(cols_to_drop,axis=1,inplace=True)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# coal_elec_per_capita           15718
# gas_electricity                15199
# oil_electricity                15164
# coal_electricity               15103
# fossil_electricity             15084
# nuclear_cons_change_twh        14976
# nuclear_consumption            14837
# electricity_generation         14401
# gas_prod_change_pct            14038
# low_carbon_electricity         13815
# renewables_electricity         13703
# solar_electricity              13610
# wind_electricity               13578
# other_renewable_electricity    13386
# hydro_electricity              12752
# coal_prod_change_pct           12156
# nuclear_electricity            12130
# oil_prod_change_pct            12019
# gdp                            10038
# energy_cons_change_twh          9898
# primary_energy_consumption      9633
# coal_prod_per_capita            7050
# gas_prod_per_capita             6856
# oil_prod_per_capita             6378
# coal_prod_change_twh            5520
# coal_production                 5265
# gas_prod_change_twh             5227
# gas_production                  4972
# oil_prod_change_twh             4588
# oil_production                  4331
# population                      3365
# dtype: int64

# %%
df['pec_copy'] = df['primary_energy_consumption'].ffill()

# %%
df[['population', 'gdp']] = df[['population', 'gdp']].ffill()

# %%
trend_cols = [
    'nuclear_consumption', 'oil_production', 'energy_cons_change_twh'
]
df[trend_cols] = df[trend_cols].interpolate(method='linear')

# %%
change_cols = [
    'coal_prod_change_twh', 'gas_prod_change_twh', 'oil_prod_change_twh',
    'coal_prod_change_pct', 'gas_prod_change_pct', 'oil_prod_change_pct',
    'energy_cons_change_twh'
]
df[change_cols] = df[change_cols].ffill()

# %%
elec_cols = [
    'electricity_generation', 'solar_electricity', 'wind_electricity', 'hydro_electricity',
    'coal_electricity', 'oil_electricity', 'gas_electricity', 'nuclear_electricity',
    'fossil_electricity', 'low_carbon_electricity', 'renewables_electricity'
]
df[elec_cols] = df[elec_cols].ffill().interpolate(method='linear')

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# coal_elec_per_capita           15718
# nuclear_cons_change_twh        14976
# other_renewable_electricity    13386
# primary_energy_consumption      9633
# coal_prod_per_capita            7050
# gas_prod_per_capita             6856
# oil_prod_per_capita             6378
# coal_production                 5265
# gas_production                  4972
# nuclear_consumption              212
# oil_prod_change_pct              159
# oil_prod_change_twh              105
# energy_cons_change_twh           105
# pec_copy                         104
# oil_production                   104
# gas_prod_change_pct               92
# gdp                               74
# coal_prod_change_pct              74
# gas_prod_change_twh               25
# coal_prod_change_twh              25
# population                        24
# oil_electricity                    0
# nuclear_electricity                0
# low_carbon_electricity             0
# gas_electricity                    0
# fossil_electricity                 0
# electricity_generation             0
# coal_electricity                   0
# renewables_electricity             0
# solar_electricity                  0
# wind_electricity                   0
# hydro_electricity                  0
# dtype: int64

# %%
cols_to_drop.clear()

# %%
cols_to_drop.extend(['coal_elec_per_capita','nuclear_cons_change_twh','other_renewable_electricity'])

# %%
df.drop(columns=cols_to_drop,inplace=True)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# primary_energy_consumption    9633
# coal_prod_per_capita          7050
# gas_prod_per_capita           6856
# oil_prod_per_capita           6378
# coal_production               5265
# gas_production                4972
# nuclear_consumption            212
# oil_prod_change_pct            159
# oil_prod_change_twh            105
# energy_cons_change_twh         105
# oil_production                 104
# pec_copy                       104
# gas_prod_change_pct             92
# gdp                             74
# coal_prod_change_pct            74
# gas_prod_change_twh             25
# coal_prod_change_twh            25
# population                      24
# nuclear_electricity              0
# oil_electricity                  0
# gas_electricity                  0
# electricity_generation           0
# low_carbon_electricity           0
# hydro_electricity                0
# coal_electricity                 0
# renewables_electricity           0
# solar_electricity                0
# wind_electricity                 0
# fossil_electricity               0
# dtype: int64

# %%
sns.boxplot(y=df['pec_copy'])
# Out:
# <Axes: ylabel='pec_copy'>

# %%
df['primary_energy_consumption'].mode()
# Out:
# 0    0.0
# Name: primary_energy_consumption, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
import pandas as pd

temp_df = df

features = ['wind_electricity','solar_electricity','renewables_electricity','oil_prod_change_twh','oil_production','oil_electricity','nuclear_consumption',
           'nuclear_electricity','gas_production','hydro_electricity','low_carbon_electricity','gas_prod_change_twh','gas_electricity','fossil_electricity',
           'energy_cons_change_twh','electricity_generation','coal_production','coal_prod_change_twh','coal_electricity','gdp','population']  # Choose relevant columns

train = temp_df[temp_df["primary_energy_consumption"].notnull()].dropna(subset=features)
test = temp_df[temp_df["primary_energy_consumption"].isnull()]

test = test.dropna(subset=features)

model = LinearRegression()
model.fit(train[features], train["primary_energy_consumption"])
# Out:
# LinearRegression()

# %%
missing_indices = temp_df[temp_df["primary_energy_consumption"].isnull()].index

test = test.dropna(subset=features)

predictions = model.predict(test[features])

temp_df.loc[missing_indices[:len(predictions)], "primary_energy_consumption"] = predictions

temp_df["primary_energy_consumption"].fillna(temp_df["primary_energy_consumption"].median(), inplace=True)

# %%
temp_df['primary_energy_consumption'].isnull().sum()
# Out:
# 0

# %%
df["primary_energy_consumption"] = temp_df["primary_energy_consumption"]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df.corr(),annot=True,fmt='.2f',cmap='Blues')
# Out:
# <Axes: >

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# coal_prod_per_capita          7050
# gas_prod_per_capita           6856
# oil_prod_per_capita           6378
# coal_production               5265
# gas_production                4972
# nuclear_consumption            212
# oil_prod_change_pct            159
# oil_prod_change_twh            105
# energy_cons_change_twh         105
# oil_production                 104
# pec_copy                       104
# gas_prod_change_pct             92
# coal_prod_change_pct            74
# gdp                             74
# gas_prod_change_twh             25
# coal_prod_change_twh            25
# population                      24
# fossil_electricity               0
# nuclear_electricity              0
# oil_electricity                  0
# low_carbon_electricity           0
# hydro_electricity                0
# gas_electricity                  0
# coal_electricity                 0
# primary_energy_consumption       0
# renewables_electricity           0
# solar_electricity                0
# wind_electricity                 0
# electricity_generation           0
# dtype: int64

# %%
sns.scatterplot(data=df,y='primary_energy_consumption',x='coal_prod_per_capita')
# Out:
# <Axes: xlabel='coal_prod_per_capita', ylabel='primary_energy_consumption'>

# %%
sns.scatterplot(data=df,y='primary_energy_consumption',x='gas_prod_per_capita')
# Out:
# <Axes: xlabel='gas_prod_per_capita', ylabel='primary_energy_consumption'>

# %%
list = [
    "oil_prod_per_capita",
    "coal_production",
    "gas_production",
    "nuclear_consumption",
    "oil_prod_change_pct",
    "oil_prod_change_twh",
    "energy_cons_change_twh",
    "oil_production",
    "pec_copy",
    "gas_prod_change_pct",
    "coal_prod_change_pct",
    "gdp",
    "gas_prod_change_twh",
    "coal_prod_change_twh",
    "population",
    "fossil_electricity",
    "nuclear_electricity",
    "oil_electricity",
    "low_carbon_electricity",
    "hydro_electricity",
    "gas_electricity",
    "coal_electricity",
    "primary_energy_consumption",
    "renewables_electricity",
    "solar_electricity",
    "wind_electricity",
    "electricity_generation"
]

# %%
for col in list:
    plt.figure(figsize=(6, 4))
    sns.scatterplot(data=df, y="primary_energy_consumption", x=col)
    plt.title(f"Scatter Plot: {col} vs Primary Energy Consumption")
    plt.show()

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df.corr(),annot=True,fmt='.2f',cmap='Blues')
# Out:
# <Axes: >

# %%
cols_to_drop.clear()

# %%
cols_to_drop.extend(['fossil_electricity','hydro_electricity','low_carbon_electricity','renewables_electricity'])

# %%
df.drop(columns=cols_to_drop,inplace=True)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df.corr(),annot=True,fmt='.2f',cmap='Blues')
# Out:
# <Axes: >

# %%
cols_to_drop.clear()

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# coal_prod_per_capita          7050
# gas_prod_per_capita           6856
# oil_prod_per_capita           6378
# coal_production               5265
# gas_production                4972
# nuclear_consumption            212
# oil_prod_change_pct            159
# oil_prod_change_twh            105
# energy_cons_change_twh         105
# oil_production                 104
# pec_copy                       104
# gas_prod_change_pct             92
# gdp                             74
# coal_prod_change_pct            74
# gas_prod_change_twh             25
# coal_prod_change_twh            25
# population                      24
# gas_electricity                  0
# nuclear_electricity              0
# oil_electricity                  0
# electricity_generation           0
# coal_electricity                 0
# primary_energy_consumption       0
# solar_electricity                0
# wind_electricity                 0
# dtype: int64

# %%
df.corr()['primary_energy_consumption'].sort_values(ascending=False)
# Out:
# primary_energy_consumption    1.000000
# gas_production                0.822593
# coal_production               0.794032
# oil_production                0.645431
# oil_electricity               0.578489
# nuclear_consumption           0.566382
# pec_copy                      0.535553
# electricity_generation        0.447542
# gdp                           0.439008
# coal_electricity              0.430911
# nuclear_electricity           0.422814
# population                    0.398522
# gas_electricity               0.392506
# coal_prod_change_twh          0.354614
# energy_cons_change_twh        0.348855
# gas_prod_change_twh           0.289244
# wind_electricity              0.257218
# oil_prod_change_twh           0.238614
# solar_electricity             0.228028
# coal_prod_per_capita          0.105526
# gas_prod_per_capita           0.005430
# coal_prod_change_pct          0.001741
# gas_prod_change_pct          -0.001864
# oil_prod_change_pct          -0.006216
# oil_prod_per_capita          -0.012772
# Name: primary_energy_consumption, dtype: float64

# %%
df.drop('pec_copy',axis=1,inplace=True)

# %%
df.corr()['primary_energy_consumption'].sort_values(ascending=False)
# Out:
# primary_energy_consumption    1.000000
# gas_production                0.822593
# coal_production               0.794032
# oil_production                0.645431
# oil_electricity               0.578489
# nuclear_consumption           0.566382
# electricity_generation        0.447542
# gdp                           0.439008
# coal_electricity              0.430911
# nuclear_electricity           0.422814
# population                    0.398522
# gas_electricity               0.392506
# coal_prod_change_twh          0.354614
# energy_cons_change_twh        0.348855
# gas_prod_change_twh           0.289244
# wind_electricity              0.257218
# oil_prod_change_twh           0.238614
# solar_electricity             0.228028
# coal_prod_per_capita          0.105526
# gas_prod_per_capita           0.005430
# coal_prod_change_pct          0.001741
# gas_prod_change_pct          -0.001864
# oil_prod_change_pct          -0.006216
# oil_prod_per_capita          -0.012772
# Name: primary_energy_consumption, dtype: float64

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder
from sklearn.impute import SimpleImputer

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso,ElasticNet
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split, cross_val_score

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21813 entries, 0 to 21812
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   population                  21789 non-null  float64
#  1   gdp                         21739 non-null  float64
#  2   coal_electricity            21813 non-null  float64
#  3   coal_prod_change_pct        21739 non-null  float64
#  4   coal_prod_change_twh        21788 non-null  float64
#  5   coal_prod_per_capita        14763 non-null  float64
#  6   coal_production             16548 non-null  float64
#  7   electricity_generation      21813 non-null  float64
#  8   energy_cons_change_twh      21708 non-null  float64
#  9   gas_electricity             21813 non-null  float64
#  10  gas_prod_change_pct         21721 non-null  float64
#  11  gas_prod_change_twh         21788 non-null  float64
#  12  gas_prod_per_capita         14957 non-null  float64
#  13  gas_production              16841 non-null  float64
#  14  nuclear_consumption         21601 non-null  float64
#  15  nuclear_electricity         21813 non-null  float64
#  16  oil_electricity             21813 non-null  float64
#  17  oil_prod_change_pct         21654 non-null  float64
#  18  oil_prod_change_twh         21708 non-null  float64
#  19  oil_prod_per_capita         15435 non-null  float64
#  20  oil_production              21709 non-null  float64
#  21  primary_energy_consumption  21813 non-null  float64
#  22  solar_electricity           21813 non-null  float64
#  23  wind_electricity            21813 non-null  float64
# dtypes: float64(24)
# memory usage: 4.0 MB

# %%
num_cols = [
    "population", "gdp", "coal_electricity", "coal_prod_change_pct", "coal_prod_change_twh",
    "coal_prod_per_capita", "coal_production", "electricity_generation", "energy_cons_change_twh",
    "gas_electricity", "gas_prod_change_pct", "gas_prod_change_twh", "gas_prod_per_capita",
    "gas_production", "nuclear_consumption", "nuclear_electricity", "oil_electricity",
    "oil_prod_change_pct", "oil_prod_change_twh", "oil_prod_per_capita", "oil_production",
    "primary_energy_consumption", "solar_electricity", "wind_electricity"
]

num_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="mean")),  
    ("scaler", StandardScaler())               
])

preprocessor = ColumnTransformer([
    ("num", num_pipeline, num_cols)  
])

# %%
df_transformed = preprocessor.fit_transform(df)

df_processed = pd.DataFrame(df_transformed, columns=num_cols)

# %%
df_processed.to_csv('cleaned.csv')
